# %% [markdown]
# <a href="https://colab.research.google.com/github/mohith-04/AI-Learning/blob/main/rag22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install langchain-community pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 46.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.5/349.5 kB 17.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 35.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 4.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("/content/drive/MyDrive/Colab Notebooks/employee_policy.pdf.pdf")

documents = loader.load()

# %%
print(documents[1].metadata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4865/1571310520.py in <cell line: 0>()
# ----> 1 print(documents[1].metadata)
#
# NameError: name 'documents' is not defined

# %%
from langchain_community.document_loaders import DirectoryLoader
loader = DirectoryLoader("documents")
documents = loader.load()

from langchain_community.document_loaders import TextLoader
loader = TextLoader("notes.txt")
documents = loader.load()



from langchain_community.document_loaders import DirectoryLoader
loader = DirectoryLoader("documents")
documents = loader.load()

#accepts only pdfs
loader = DirectoryLoader(
    "documents",
    glob="*.pdf"
)

#this loads files from all sub folders
loader = DirectoryLoader(
    "documents",
    recursive=True
)

from langchain_community.document_loaders import CSVLoader
loader = CSVLoader("employees.csv")
documents = loader.load()


# for .md files
from langchain_community.document_loaders import UnstructuredMarkdownLoader
loader = UnstructuredMarkdownLoader("README.md")
documents = loader.load()

# | Loader                       | File Type | Typical Use Case                |
# | ---------------------------- | --------- | ------------------------------- |
# | `PyPDFLoader`                | PDF       | Books, manuals, research papers |
# | `TextLoader`                 | TXT       | Notes, logs, plain text         |
# | `DirectoryLoader`            | Folder    | Bulk loading many files         |
# | `CSVLoader`                  | CSV       | Structured tabular data         |
# | `UnstructuredMarkdownLoader` | Markdown  | Documentation, GitHub READMEs   |

# %%
# !pip install langchain-huggingface

# %%
# !pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 58.1 MB/s eta 0:00:00
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS


loader = PyPDFLoader("/content/drive/MyDrive/Colab Notebooks/employee_policy.pdf.pdf")
documents = loader.load()

print(f"Loaded {len(documents)} pages.\n")


text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

chunks = text_splitter.split_documents(documents)

print(f"Created {len(chunks)} chunks.\n")
print("First Chunk:\n")
print(chunks[0].page_content)


embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)


vectorstore = FAISS.from_documents(
    documents=chunks,
    embedding=embeddings
)

print("FAISS Vector Store Created Successfully!\n")



retriever = vectorstore.as_retriever(
    search_kwargs={"k": 3}
)

while True:

    question = input("\nAsk a Question (type 'exit' to quit): ")

    if question.lower() == "exit":
        break

    results = retriever.invoke(question)

    print("\nTop Relevant Chunks\n")


    for i, doc in enumerate(results, start=1):

        print(f"\nChunk {i}")

        print(doc.page_content)
        print("\nSource:", doc.metadata)
# Out:
# Loaded 11 pages.
#
# Created 63 chunks.
#
# First Chunk:
#
# APEAPCET-2026 ADMISSIONS
# (M.P.C. STREAM)
# FIRST PHASE
#
#
#
# The Qualified and elig ible candidates of AP EAPCET-2026, desirous of seeking
# admission into B.E/B.Tech   Courses are informed that the web counse lling process
# comprising the payment of  processing fee cum registration, online certificate verification
# and option entry will be conducted from 20 -07-2026 to 01 -08-2026. The candidates are
# instructed to follow guidelines/Instructions to  candidates or user manual  to proceed for
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# FAISS Vector Store Created Successfully!
#
#
# Ask a Question (type 'exit' to quit): dates for ap eamcet councelling
#
# Top Relevant Chunks
#
#
# Chunk 1
# APEAPCET-2026 ADMISSIONS
# (M.P.C. STREAM)
# FIRST PHASE
#
#
#
# The Qualified and elig ible candidates of AP EAPCET-2026, desirous of seeking
# ...
